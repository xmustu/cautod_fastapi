# %%
docker run -id --name=rabbitmq -v D:/CAutoD/docker/rabbitmq:/var/lib/rabbitmq -p 15672:15672 -p 5672:5672 -e RABBITMQ_DEFAULT_USER=admin -e RABBITMQ_DEFAULT_PASS=admin rabbitmq:4.2.0-rc.1-management

# %%
D:\CAutoD\docker
